# %% [markdown]
# ## Check training results

# %% [markdown]
# ### Value function

# %%
import pickle 
from utils import plot_valuefunc_and_policy
from first_visit import FirstVisitMC

# %%
mc = pickle.load(open('output/mc.pkl', 'rb'))

# %%
plot_valuefunc_and_policy(mc.Q)

# %% [markdown]
# ### Run an episode with the trained policy

# %%
mc.generate_episode(render=True)

# %% [markdown]
# ---

# %% [markdown]
# ### Some debugging

# %%
from first_visit import FirstVisitMC
import gym

env = gym.make('FrozenLake8x8-v1', is_slippery=False)

mc = FirstVisitMC(env, gamma=.99, eps=.4)
# Out:
# /Users/leodamato/.python-envs/rl-env/lib/python3.10/site-packages/gym/wrappers/monitoring/video_recorder.py:1: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   import distutils.spawn

# %%
mc.policy[:,0]
# Out:
# array([0.17589982, 0.32525662, 0.21264262, 0.28620095])

# %%
mc.Q[:,0]
# Out:
# array([0.18042144, 0.81437484, 0.36155186, 0.14546383])

# %%
mc.train(n_episodes=1000, )
# Out:
# 100%|██████████| 1000/1000 [00:07<00:00, 136.50it/s]

# %%
from utils import plot_valuefunc_and_policy
plot_valuefunc_and_policy(mc.Q, savefig=False)
